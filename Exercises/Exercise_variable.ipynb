# %% [markdown]
# # Exercise: Python Variables

# %% [markdown]
# ### Create a variable called break and assign it a value 5. See what happens and find out the reason behind the behavior that you see.

# %%
break=5
# Out:
#   Cell In[3], line 1
#     break=5
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# why this error: because break is keyword in and we can't assign values to keywords

# %% [markdown]
# ### Create two variables. One to store your birth year and another one to store current year. Now calculate your age using these two variables

# %%
birth_year=1990
current_year=2026
age=current_year - birth_year 
print(age)
# Out:
# 36

# %% [markdown]
# ### Store your first, middle and last name in three different variables and then print your full name using these variables

# %%
fir_nm= "Nadeeka"
sec_nm="Malkanthi"
last_nm = "Kiringoda Arachchige"
full_name= fir_nm +  " " + sec_nm + " " + last_nm
print(full_name)
# Out:
# Nadeeka Malkanthi Kiringoda Arachchige

# %%
#Answer which of these are invalid variable names: _nation 1record record1 record_one record-one record^one continue

# %%
variables = [
    "_nation",
    "1record",
    "record1",
    "record_one",
    "record-one",
    "record^one",
    "continue"
]

for var in variables:
    print(var, ":", var.isidentifier())
# Out:
# _nation : True
# 1record : False
# record1 : True
# record_one : True
# record-one : False
# record^one : False
# continue : True
