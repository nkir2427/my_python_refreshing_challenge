# %% [markdown]
# # Exercise: Python Lists

# %% [markdown]
# #### Let us say your expense for every month are listed below,
# January - 2200
# February - 2350
# March - 2600
# April - 2130
# May - 2190
# Create a list to store these monthly expenses and using that find out,
#
# 1. In Feb, how many dollars you spent extra compare to January?
# 2. Find out your total expense in first quarter (first three months) of the year.
# 3. Find out if you spent exactly 2000 dollars in any month
# 4. June month just finished and your expense is 1980 dollar. Add this item to our monthly expense list
# 5. You returned an item that you bought in a month of April and
# got a refund of 200$. Make a correction to your monthly expense list
# based on this

# %%
monthly_expenses=[2200,2350,2600,2130,2190]
print(monthly_expenses)
# Out:
# [2200, 2350, 2600, 2130, 2190]

# %%
print("Feb_extra_expenses:",(monthly_expenses[1] - monthly_expenses[0]) )
print("First Quarter Expenses:",(monthly_expenses[0] + monthly_expenses[1] + monthly_expenses[2]))
print("if spent 2000 :",2000 in monthly_expenses)
monthly_expenses.append(1980)
print("after june:",monthly_expenses)
apr_new_expenses=monthly_expenses[3]+200
apr_new_expenses
monthly_expenses[3]=apr_new_expenses 
print("with april new expenses" ,monthly_expenses)
# Out:
# Feb_extra_expenses: 150
# First Quarter Expenses: 7150
# if spent 2000 : False
# after june: [2200, 2350, 2600, 2130, 2190, 1980]
# with april new expenses [2200, 2350, 2600, 2330, 2190, 1980]

# %% [markdown]
# #### You have a list of your favourite marvel super heros.
# heros=['spider man','thor','hulk','iron man','captain america']
# Using this find out,
#
# 1. Length of the list
# 2. Add 'black panther' at the end of this list
# 3. You realize that you need to add 'black panther' after 'hulk',
#    so remove it from the list first and then add it after 'hulk'
# 4. Now you don't like thor and hulk because they get angry easily :)
#    So you want to remove thor and hulk from list and replace them with doctor strange (because he is cool).
#    Do that with one line of code.
# 5. Sort the heros list in alphabetical order (Hint. Use dir() functions to list down all functions available in list)

# %%
heros=['spider man','thor','hulk','iron man','captain america']
heros
# Out:
# ['spider man', 'thor', 'hulk', 'iron man', 'captain america']

# %%
print("1.length of the heros list:",len(heros))
heros.append("black panther")
print("2:",heros)
heros.remove("black panther")
heros.insert(3,"black panther")
print("3:",heros)
heros[1:3]=["doctor strange","doctor strange"]
print("4:",heros)
heros.sort()
print("5:",heros)
# Out:
# 1.length of the heros list: 5
# 2: ['spider man', 'thor', 'hulk', 'iron man', 'captain america', 'black panther']
# 3: ['spider man', 'thor', 'hulk', 'black panther', 'iron man', 'captain america']
# 4: ['spider man', 'doctor strange', 'doctor strange', 'black panther', 'iron man', 'captain america']
# 5: ['black panther', 'captain america', 'doctor strange', 'doctor strange', 'iron man', 'spider man']
